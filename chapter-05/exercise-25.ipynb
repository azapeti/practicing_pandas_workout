# %%
import pandas as pd
import numpy as np
from pandas import Series, DataFrame

# %%
df= pd.read_csv(
    '../../../data/nyc-parking-violations-2020.csv',
    sep= ',',
    usecols= ['Plate ID', 'Registration State', 'Vehicle Make', 'Vehicle Color', 'Violation Time', 'Street Name']
    )

# %%
df
# Out:
#           Plate ID Registration State Vehicle Make Violation Time  \
# 0           J58JKX                 NJ        HONDA          0523P
# 1          KRE6058                 PA        ME/BE          0428P
# 2          444326R                 NJ        LEXUS          0625A
# 3          F728330                 OH        CHEVR          1106A
# 4          FMY9090                 NY         JEEP          1253A
# ...            ...                ...          ...            ...
# 12495729   62161MM                 NY         FORD          1111A
# 12495730   GYE7330                 NY        HONDA          0444P
# 12495731   HNY4802                 NY         FORD          0210A
# 12495732  T687081C                 NY        TOYOT          0225P
# 12495733    3497ZN                 WA        UTILI          0456A
#
#                Street Name Vehicle Color
# 0                    43 ST            BK
# 1                 UNION ST           BLK
# 2          CLERMONT AVENUE         BLACK
# ...

# %%
# How many rows are in the data frame when it is read into memory?
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 12495734 entries, 0 to 12495733
# Data columns (total 6 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   Plate ID            str
#  1   Registration State  str
#  2   Vehicle Make        str
#  3   Violation Time      str
#  4   Street Name         str
#  5   Vehicle Color       str
# dtypes: str(6)
# memory usage: 572.0 MB

# %%
# How many rows are in the data frame when it is read into memory?
len(df)
# Out:
# 12495734

# %%
# Remove rows with any missing data (i.e., a NaN value).

# How many rows remain after doing this pruning?

df_na_dropped = df.dropna()
len(df_na_dropped)
# Out:
# 12048375

# %%
# If each parking ticket brings $100 into the city, and
# missing data means the ticket can be successfully contested, how much money
# may New York City lose due to such missing data?

potential_loss = (len(df) - len(df_na_dropped)) * 100
print(f"${potential_loss:,}")
# Out:
# $44,735,900

# %%
# Let’s instead assume that a ticket can only be dismissed if the license plate,
# state, car make, and/or street name are missing. Remove rows that are missing
# one or more of these. How many rows remain? Assuming $100/ticket, how
# much money would the city lose as a result of this missing data?

df_crticical_na_dropped = (
    df.dropna(subset= [
        'Plate ID',
        'Registration State',
        'Vehicle Make',
        'Street Name'
    ])
)

potential_loss_2 = (len(df) - len(df_crticical_na_dropped)) * 100
print(f"${potential_loss_2:,}")
# Out:
# $6,378,500

# %%
# Now let’s assume that tickets can be dismissed if the license plate, state, and/or
# street name are missing—that is, the same as the previous question, but without
# requiring the make of car. Remove rows that are missing one or more of these.
# How many rows remain? Assuming $100/ticket, how much money would the
# city lose as a result of this missing data?

df_crticical_na_dropped_2 = (
    df.dropna(subset= [
        'Plate ID',
        'Registration State',
        'Street Name'
    ])
)

potential_loss_3 = (len(df) - len(df_crticical_na_dropped_2)) * 100
print(f"${potential_loss_3:,}")
# Out:
# $161,800

# %% [markdown]
# #### Beyond the exercise_1
# ##### So far, you have specified which columns must be all non-null. But sometimes it’s OK for some columns to have null values, as long as it’s not too many. How many rows would you eliminate if you required at least three non-null values from the four columns `Plate ID`, `Registration State`, `Vehicle Make`, and `Street Name`?

# %%
df_bte_1 = (
    df.dropna(subset= [
        'Plate ID',
        'Registration State',
        'Vehicle Make',
        'Street Name'
    ],
    thresh= 3)
)

# %%
print(f'{len(df) - len(df_bte_1):,}')
# Out:
# 253

# %% [markdown]
# #### Beyond the exercise_2
# ##### Which of the columns you’ve imported has the greatest number of `NaN` values? Is this a problem?

# %%
cols = ['Plate ID', 'Registration State', 'Vehicle Make', 'Street Name']

for col in cols:
    print(f'{col} col has {df[col].isna().sum()} NaN values')
# Out:
# Plate ID col has 202 NaN values
# Registration State col has 0 NaN values
# Vehicle Make col has 62420 NaN values
# Street Name col has 1417 NaN values

# %% [markdown]
# #### Beyond the exercise_3
# ##### Null data is bad, but there is plenty of bad non-null data, too. For example, many cars with `BLANKPLATE` as a plate ID were ticketed. Turn these into `NaN` values, and rerun the previous query.

# %%
df_mod = df.copy()

# df_mod['Plate ID'] = df_mod['Plate ID'].replace('BLANKPLATE', np.nan)

df_mod['Plate ID'] = df_mod['Plate ID'].apply(lambda x: np.nan if x == 'BLANKPLATE' else x)

for col in cols:
    print(f'{col} col has {df_mod[col].isna().sum()} NaN values')
# Out:
# Plate ID col has 9084 NaN values
# Registration State col has 0 NaN values
# Vehicle Make col has 62420 NaN values
# Street Name col has 1417 NaN values
