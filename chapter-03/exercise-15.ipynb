# %%
import pandas as pd
import numpy as np
from pandas import Series, DataFrame

# %%
df = (
    pd.read_csv('../../../data/nyc_taxi_2019-01.csv',
    sep= ',',
    header= 0,
    usecols = ['passenger_count', 'trip_distance', 'total_amount', 'payment_type'])
)

# %%
df.memory_usage()
# Out:
# Index                   132
# passenger_count    61342336
# trip_distance      61342336
# payment_type       61342336
# total_amount       61342336
# dtype: int64

# %% [markdown]
# #### How many taxi rides had more than eight passengers?

# %%
len(df.query('passenger_count > 8'))
# Out:
# 9

# %%
len(df[df['passenger_count'] > 8])
# Out:
# 9

# %%
import time

# Method 1: Using df.query()
start_time = time.perf_counter()
result1 = len(df.query('passenger_count > 8'))
query_time = time.perf_counter() - start_time

# Method 2: Using boolean indexing
start_time = time.perf_counter()
result2 = len(df[df['passenger_count'] > 8])
indexing_time = time.perf_counter() - start_time

print(f"Query method time: {query_time:.6f} seconds, Result: {result1}")
print(f"Boolean indexing time: {indexing_time:.6f} seconds, Result: {result2}")
# Out:
# Query method time: 0.142469 seconds, Result: 9
# Boolean indexing time: 0.031551 seconds, Result: 9

# %%
import time

# Method 1: Using df.query()
start_time = time.perf_counter()
result1 = len(df.query('passenger_count > 8'))
query_time = time.perf_counter() - start_time

# Method 2: Using boolean indexing
start_time = time.perf_counter()
result2 = len(df[df['passenger_count'] > 8])
indexing_time = time.perf_counter() - start_time

print(f"Query method time: {query_time:.6f} seconds, Result: {result1}")
print(f"Boolean indexing time: {indexing_time:.6f} seconds, Result: {result2}")
# Out:
# Query method time: 0.116331 seconds, Result: 9
# Boolean indexing time: 0.014359 seconds, Result: 9

# %% [markdown]
# #### How many taxi rides had zero passengers?

# %%
len(df.query('passenger_count == 0'))
# Out:
# 117381

# %% [markdown]
# #### How many taxi rides were paid for in cash and cost over $1,000?

# %%
len(df.query('payment_type == 2 & total_amount > 1000'))
# Out:
# 5

# %% [markdown]
# #### How many rides cost less than $0?

# %%
len(df.query('total_amount < 0'))
# Out:
# 7131

# %% [markdown]
# #### How many rides traveled a below-average distance but cost an above-average amount?

# %%
mean_distance = df['trip_distance'].mean()
mean_cost = df['total_amount'].mean()

len(df.query('trip_distance < @mean_distance & total_amount > @mean_cost'))
# Out:
# 411255

# %%
df.head()
# Out:
#    passenger_count  trip_distance  payment_type  total_amount
# 0                1            1.5             1          9.95
# 1                1            2.6             1         16.30
# 2                3            0.0             1          5.80
# 3                5            0.0             2          7.55
# 4                5            0.0             2         55.55

# %%
df.loc[
    (df['trip_distance'] < df['trip_distance'].mean()) &
    (df['total_amount'] > df['total_amount'].mean()),
    'payment_type'
].count()
# Out:
# np.int64(411255)

# %%
df.payment_type.value_counts()
# Out:
# payment_type
# 1    5486027
# 2    2137415
# 3      33186
# 4      11164
# Name: count, dtype: int64

# %% [markdown]
# #### Beyond the exercise_1
# ##### Repeat this exercise using the query method rather than a boolean index and loc

# %%
# I did this way so i skip this task

# %% [markdown]
# #### Beyond the exercise_2
# ##### How many rides that cost less than $0 involved either a dispute (payment_type of 4) or a voided trip (payment_type of 6)?

# %%
df.loc[
    (df['total_amount'] < 0) &
    ((df['payment_type'] == 4) | (df['payment_type'] == 6)), 'payment_type'
].value_counts()

# NOTE: here might be a printing error in the book because there is no payment category 6.
# Out:
# payment_type
# 4    2666
# Name: count, dtype: int64

# %% [markdown]
# ####  Beyond the exercise_3
#
# ##### I stated earlier that most people pay for taxi rides using a credit card. Show this, and find what percentage normally pays in cash versus a credit card.

# %%
credit_card_payment = len(df.loc[df['payment_type'] == 1])
cash_payment = len(df.loc[df['payment_type'] == 2])
all_payment = len(df['payment_type'])

print(f'{credit_card_payment/all_payment*100:.4f}% of the trips were paid by credit card and {cash_payment/all_payment*100:.4f}% were paid with cash.')
# Out:
# 71.5464% of the trips were paid by credit card and 27.8752% were paid with cash.

# %%
df['payment_type'].value_counts(normalize = True)[[1,2]]*100
# Out:
# payment_type
# 1    71.546372
# 2    27.875234
# Name: proportion, dtype: float64
