# %%
import pandas as pd
import numpy as np
from pandas import Series, DataFrame

# %%
df = pd.read_csv(
    '../../../data/linux-etc-passwd.txt',
    sep= '.',
    header= None,
    names= ['username', 'password', 'userid', 'groupid', 'name', 'homedir', 'shell'],
    index_col= 'username'
)

# %%
df
# Out:
#                                                                              password  \
# username
# # This is a comment                                                               NaN
# # You should ignore me                                                            NaN
# root:x:0:0:root:/root:/bin/bash                                                   NaN
# daemon:x:1:1:daemon:/usr/sbin:/usr/sbin/nologin                                   NaN
# bin:x:2:2:bin:/bin:/usr/sbin/nologin                                              NaN
# sys:x:3:3:sys:/dev:/usr/sbin/nologin                                              NaN
# sync:x:4:65534:sync:/bin:/bin/sync                                                NaN
# games:x:5:60:games:/usr/games:/usr/sbin/nologin                                   NaN
# man:x:6:12:man:/var/cache/man:/usr/sbin/nologin                                   NaN
# lp:x:7:7:lp:/var/spool/lpd:/usr/sbin/nologin                                      NaN
# mail:x:8:8:mail:/var/mail:/usr/sbin/nologin                                       NaN
# news:x:9:9:news:/var/spool/news:/usr/sbin/nologin                                 NaN
# uucp:x:10:10:uucp:/var/spool/uucp:/usr/sbin/nol...                                NaN
# proxy:x:13:13:proxy:/bin:/usr/sbin/nologin                                        NaN
# www-data:x:33:33:www-data:/var/www:/usr/sbin/no...                                NaN
# backup:x:34:34:backup:/var/backups:/usr/sbin/no...                                NaN
# list:x:38:38:Mailing List Manager:/var/list:/us...                                NaN
# irc:x:39:39:ircd:/var/run/ircd:/usr/sbin/nologin                                  NaN
# gnats:x:41:41:Gnats Bug-Reporting System (admin...                                NaN
# nobody:x:65534:65534:nobody:/nonexistent:/usr/s...                                NaN
# syslog:x:101:104::/home/syslog:/bin/false                                         NaN
# messagebus:x:102:106::/var/run/dbus:/bin/false                                    NaN
# landscape:x:103:109::/var/lib/landscape:/bin/false                                NaN
# jci:x:955:955::/home/jci:/bin/bash                                                NaN
# sshd:x:104:65534::/var/run/sshd:/usr/sbin/nologin                                 NaN
# user:x:1000:1000:user,,,:/home/user:/bin/bash                                     NaN
# reuven:x:1001:1001:Reuven M                          Lerner,,,:/home/reuven:/bin/bash
# postfix:x:105:113::/var/spool/postfix:/bin/false                                  NaN
# colord:x:106:116:colord colour management daemo...                                NaN
# postgres:x:107:117:PostgreSQL administrator,,,:...                                NaN
# dovecot:x:108:119:Dovecot mail server,,,:/usr/l...                                NaN
# dovenull:x:109:120:Dovecot login user,,,:/nonex...                                NaN
# postgrey:x:110:121::/var/lib/postgrey:/bin/false                                  NaN
# debian-spamd:x:111:122::/var/lib/spamassassin:/...                                NaN
# memcache:x:113:124:Memcached,,,:/nonexistent:/b...                                NaN
# genadi:x:1002:1003:Genadi Reznichenko,,,:/home/...                                NaN
# shira:x:1003:1004:Shira Friedman,,,:/home/shira...                                NaN
# atara:x:1004:1005:Atara Lerner-Friedman,,,:/hom...                                NaN
# shikma:x:1005:1006:Shikma Lerner-Friedman,,,:/h...                                NaN
# amotz:x:1006:1007:Amotz Lerner-Friedman,,,:/hom...                                NaN
# mysql:x:114:125:MySQL Server,,,:/nonexistent:/b...                                NaN
# clamav:x:115:126::/var/lib/clamav:/bin/false                                      NaN
# amavis:x:116:127:AMaViS system user,,,:/var/lib...                                NaN
# opendkim:x:117:128::/var/run/opendkim:/bin/false                                  NaN
# gitlab-redis:x:999:1009::/var/opt/gitlab/redis:...                                NaN
# gitlab-psql:x:998:1010::/var/opt/gitlab/postgre...                                NaN
# git:x:1007:1008:GitLab,,,:/home/git:/bin/bash                                     NaN
# opendmarc:x:118:129::/var/run/opendmarc:/bin/false                                NaN
# dkim-milter-python:x:119:130::/var/run/dkim-mil...                                NaN
# deploy:x:1008:1011:Deploy,,,:/home/deploy:/bin/...                                NaN
# redis:x:112:123:redis server,,,:/var/lib/redis:...                                NaN
#
#                                                     userid  groupid  name  \
# username
# # This is a comment                                    NaN      NaN   NaN
# # You should ignore me                                 NaN      NaN   NaN
# root:x:0:0:root:/root:/bin/bash                        NaN      NaN   NaN
# daemon:x:1:1:daemon:/usr/sbin:/usr/sbin/nologin        NaN      NaN   NaN
# bin:x:2:2:bin:/bin:/usr/sbin/nologin                   NaN      NaN   NaN
# sys:x:3:3:sys:/dev:/usr/sbin/nologin                   NaN      NaN   NaN
# sync:x:4:65534:sync:/bin:/bin/sync                     NaN      NaN   NaN
# games:x:5:60:games:/usr/games:/usr/sbin/nologin        NaN      NaN   NaN
# man:x:6:12:man:/var/cache/man:/usr/sbin/nologin        NaN      NaN   NaN
# lp:x:7:7:lp:/var/spool/lpd:/usr/sbin/nologin           NaN      NaN   NaN
# mail:x:8:8:mail:/var/mail:/usr/sbin/nologin            NaN      NaN   NaN
# news:x:9:9:news:/var/spool/news:/usr/sbin/nologin      NaN      NaN   NaN
# uucp:x:10:10:uucp:/var/spool/uucp:/usr/sbin/nol...     NaN      NaN   NaN
# proxy:x:13:13:proxy:/bin:/usr/sbin/nologin             NaN      NaN   NaN
# www-data:x:33:33:www-data:/var/www:/usr/sbin/no...     NaN      NaN   NaN
# backup:x:34:34:backup:/var/backups:/usr/sbin/no...     NaN      NaN   NaN
# list:x:38:38:Mailing List Manager:/var/list:/us...     NaN      NaN   NaN
# irc:x:39:39:ircd:/var/run/ircd:/usr/sbin/nologin       NaN      NaN   NaN
# gnats:x:41:41:Gnats Bug-Reporting System (admin...     NaN      NaN   NaN
# nobody:x:65534:65534:nobody:/nonexistent:/usr/s...     NaN      NaN   NaN
# syslog:x:101:104::/home/syslog:/bin/false              NaN      NaN   NaN
# messagebus:x:102:106::/var/run/dbus:/bin/false         NaN      NaN   NaN
# landscape:x:103:109::/var/lib/landscape:/bin/false     NaN      NaN   NaN
# jci:x:955:955::/home/jci:/bin/bash                     NaN      NaN   NaN
# sshd:x:104:65534::/var/run/sshd:/usr/sbin/nologin      NaN      NaN   NaN
# user:x:1000:1000:user,,,:/home/user:/bin/bash          NaN      NaN   NaN
# reuven:x:1001:1001:Reuven M                            NaN      NaN   NaN
# postfix:x:105:113::/var/spool/postfix:/bin/false       NaN      NaN   NaN
# colord:x:106:116:colord colour management daemo...     NaN      NaN   NaN
# postgres:x:107:117:PostgreSQL administrator,,,:...     NaN      NaN   NaN
# dovecot:x:108:119:Dovecot mail server,,,:/usr/l...     NaN      NaN   NaN
# dovenull:x:109:120:Dovecot login user,,,:/nonex...     NaN      NaN   NaN
# postgrey:x:110:121::/var/lib/postgrey:/bin/false       NaN      NaN   NaN
# debian-spamd:x:111:122::/var/lib/spamassassin:/...     NaN      NaN   NaN
# memcache:x:113:124:Memcached,,,:/nonexistent:/b...     NaN      NaN   NaN
# genadi:x:1002:1003:Genadi Reznichenko,,,:/home/...     NaN      NaN   NaN
# shira:x:1003:1004:Shira Friedman,,,:/home/shira...     NaN      NaN   NaN
# atara:x:1004:1005:Atara Lerner-Friedman,,,:/hom...     NaN      NaN   NaN
# shikma:x:1005:1006:Shikma Lerner-Friedman,,,:/h...     NaN      NaN   NaN
# amotz:x:1006:1007:Amotz Lerner-Friedman,,,:/hom...     NaN      NaN   NaN
# mysql:x:114:125:MySQL Server,,,:/nonexistent:/b...     NaN      NaN   NaN
# clamav:x:115:126::/var/lib/clamav:/bin/false           NaN      NaN   NaN
# amavis:x:116:127:AMaViS system user,,,:/var/lib...     NaN      NaN   NaN
# opendkim:x:117:128::/var/run/opendkim:/bin/false       NaN      NaN   NaN
# gitlab-redis:x:999:1009::/var/opt/gitlab/redis:...     NaN      NaN   NaN
# gitlab-psql:x:998:1010::/var/opt/gitlab/postgre...     NaN      NaN   NaN
# git:x:1007:1008:GitLab,,,:/home/git:/bin/bash          NaN      NaN   NaN
# opendmarc:x:118:129::/var/run/opendmarc:/bin/false     NaN      NaN   NaN
# dkim-milter-python:x:119:130::/var/run/dkim-mil...     NaN      NaN   NaN
# deploy:x:1008:1011:Deploy,,,:/home/deploy:/bin/...     NaN      NaN   NaN
# redis:x:112:123:redis server,,,:/var/lib/redis:...     NaN      NaN   NaN
#
#                                                     homedir  shell
# username
# # This is a comment                                     NaN    NaN
# # You should ignore me                                  NaN    NaN
# root:x:0:0:root:/root:/bin/bash                         NaN    NaN
# daemon:x:1:1:daemon:/usr/sbin:/usr/sbin/nologin         NaN    NaN
# bin:x:2:2:bin:/bin:/usr/sbin/nologin                    NaN    NaN
# sys:x:3:3:sys:/dev:/usr/sbin/nologin                    NaN    NaN
# sync:x:4:65534:sync:/bin:/bin/sync                      NaN    NaN
# games:x:5:60:games:/usr/games:/usr/sbin/nologin         NaN    NaN
# man:x:6:12:man:/var/cache/man:/usr/sbin/nologin         NaN    NaN
# lp:x:7:7:lp:/var/spool/lpd:/usr/sbin/nologin            NaN    NaN
# mail:x:8:8:mail:/var/mail:/usr/sbin/nologin             NaN    NaN
# news:x:9:9:news:/var/spool/news:/usr/sbin/nologin       NaN    NaN
# uucp:x:10:10:uucp:/var/spool/uucp:/usr/sbin/nol...      NaN    NaN
# proxy:x:13:13:proxy:/bin:/usr/sbin/nologin              NaN    NaN
# www-data:x:33:33:www-data:/var/www:/usr/sbin/no...      NaN    NaN
# backup:x:34:34:backup:/var/backups:/usr/sbin/no...      NaN    NaN
# list:x:38:38:Mailing List Manager:/var/list:/us...      NaN    NaN
# irc:x:39:39:ircd:/var/run/ircd:/usr/sbin/nologin        NaN    NaN
# gnats:x:41:41:Gnats Bug-Reporting System (admin...      NaN    NaN
# nobody:x:65534:65534:nobody:/nonexistent:/usr/s...      NaN    NaN
# syslog:x:101:104::/home/syslog:/bin/false               NaN    NaN
# messagebus:x:102:106::/var/run/dbus:/bin/false          NaN    NaN
# landscape:x:103:109::/var/lib/landscape:/bin/false      NaN    NaN
# jci:x:955:955::/home/jci:/bin/bash                      NaN    NaN
# sshd:x:104:65534::/var/run/sshd:/usr/sbin/nologin       NaN    NaN
# user:x:1000:1000:user,,,:/home/user:/bin/bash           NaN    NaN
# reuven:x:1001:1001:Reuven M                             NaN    NaN
# postfix:x:105:113::/var/spool/postfix:/bin/false        NaN    NaN
# colord:x:106:116:colord colour management daemo...      NaN    NaN
# postgres:x:107:117:PostgreSQL administrator,,,:...      NaN    NaN
# dovecot:x:108:119:Dovecot mail server,,,:/usr/l...      NaN    NaN
# dovenull:x:109:120:Dovecot login user,,,:/nonex...      NaN    NaN
# postgrey:x:110:121::/var/lib/postgrey:/bin/false        NaN    NaN
# debian-spamd:x:111:122::/var/lib/spamassassin:/...      NaN    NaN
# memcache:x:113:124:Memcached,,,:/nonexistent:/b...      NaN    NaN
# genadi:x:1002:1003:Genadi Reznichenko,,,:/home/...      NaN    NaN
# shira:x:1003:1004:Shira Friedman,,,:/home/shira...      NaN    NaN
# atara:x:1004:1005:Atara Lerner-Friedman,,,:/hom...      NaN    NaN
# shikma:x:1005:1006:Shikma Lerner-Friedman,,,:/h...      NaN    NaN
# amotz:x:1006:1007:Amotz Lerner-Friedman,,,:/hom...      NaN    NaN
# mysql:x:114:125:MySQL Server,,,:/nonexistent:/b...      NaN    NaN
# clamav:x:115:126::/var/lib/clamav:/bin/false            NaN    NaN
# amavis:x:116:127:AMaViS system user,,,:/var/lib...      NaN    NaN
# opendkim:x:117:128::/var/run/opendkim:/bin/false        NaN    NaN
# gitlab-redis:x:999:1009::/var/opt/gitlab/redis:...      NaN    NaN
# gitlab-psql:x:998:1010::/var/opt/gitlab/postgre...      NaN    NaN
# git:x:1007:1008:GitLab,,,:/home/git:/bin/bash           NaN    NaN
# opendmarc:x:118:129::/var/run/opendmarc:/bin/false      NaN    NaN
# dkim-milter-python:x:119:130::/var/run/dkim-mil...      NaN    NaN
# deploy:x:1008:1011:Deploy,,,:/home/deploy:/bin/...      NaN    NaN
# redis:x:112:123:redis server,,,:/var/lib/redis:...      NaN    NaN
