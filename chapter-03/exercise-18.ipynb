# %%
import pandas as pd
import numpy as np
from pandas import Series, DataFrame

# %%
df = pd.read_csv(
    '../../../data/linux-etc-passwd.txt',
    sep= ':',
    header= None,
    names= ['username', 'password', 'userid', 'groupid', 'name', 'homedir', 'shell'],
    index_col= 'username',
    comment= '#'
)

# %%
df
# Out:
#                    password  userid  groupid  \
# username
# root                      x       0        0
# daemon                    x       1        1
# bin                       x       2        2
# sys                       x       3        3
# sync                      x       4    65534
# games                     x       5       60
# man                       x       6       12
# lp                        x       7        7
# mail                      x       8        8
# news                      x       9        9
# uucp                      x      10       10
# proxy                     x      13       13
# www-data                  x      33       33
# backup                    x      34       34
# list                      x      38       38
# irc                       x      39       39
# gnats                     x      41       41
# nobody                    x   65534    65534
# syslog                    x     101      104
# ...

# %% [markdown]
# ### Beyond the exercise_1
# ####  Ignore the `password` and `groupid` fields so they don’t appear in the data frame.

# %%
df = pd.read_csv(
    '../../../data/linux-etc-passwd.txt',
    sep= ':',
    header= None,
    names= ['username', 'userid', 'name', 'homedir', 'shell'],
    index_col= 'username',
    usecols= [0, 2, 4, 5, 6],
    comment= '#'
)

# %%
df
# Out:
#                     userid                                name  \
# username
# root                     0                                root
# daemon                   1                              daemon
# bin                      2                                 bin
# sys                      3                                 sys
# sync                     4                                sync
# games                    5                               games
# man                      6                                 man
# lp                       7                                  lp
# mail                     8                                mail
# news                     9                                news
# uucp                    10                                uucp
# proxy                   13                               proxy
# www-data                33                            www-data
# backup                  34                              backup
# ...

# %% [markdown]
# ### Beyond the exercise_2
# ####  Unix systems typically reserve user IDs below 1000 to special accounts. Show the nonspecial usernames in this passwd file.

# %%
list(df[df['userid'] > 999].index)
# Out:
# ['nobody',
#  'user',
#  'reuven',
#  'genadi',
#  'shira',
#  'atara',
#  'shikma',
#  'amotz',
#  'git',
#  'deploy']

# %% [markdown]
# ### Beyond the exercise_3
# ####  Immediately after logging into a Unix system, a command interpreter known as a `shell` fires up. What are the different shells in this file?

# %%
df['shell'].value_counts()
# Out:
# shell
# /usr/sbin/nologin    17
# /bin/false           15
# /bin/bash            12
# /bin/sh               3
# /bin/sync             1
# /bin/nologin          1
# Name: count, dtype: int64

# %%
#  NOTE: below is Reuven answer to this exercise:

# The `unique` method does this for us, returning a NumPy array -- but Pandas offers its own
# drop_duplicates method, which keeps us with a series

df['shell'].drop_duplicates()
